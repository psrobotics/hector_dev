# %% [markdown]
# ## Rollout trajectory for joystick policy

# %%
import jax
from jax import numpy as jp
print("backend:", jax.default_backend())  # should be 'gpu'
print("devices:", jax.devices())          # should list GpuDevice(...)

from brax.training.acme import running_statistics

from mujoco_playground import registry
from mujoco_playground.config import locomotion_params
# Out:
# backend: gpu
# devices: [CudaDevice(id=0)]

# %%
from hector_pg import constants as consts

ROOT_PATH = consts.ROOT_PATH
env_name = 'HectorJoystickFlatTerrain'
policy_path = consts.ROOT_PATH.parent / 'logs' / 'joystick' / 's1_0906_1_h20'

print(policy_path)

env = registry.load(env_name)
env_cfg = registry.get_default_config(env_name)
ppo_params = locomotion_params.brax_ppo_config(env_name)

print(env._config)
# Out:
# /home/ps/Documents/hector_dev/src/logs/joystick/s1_0906_1_h20
# l_hip_yaw: -0.79 to 0.79
# l_hip_roll: -0.79 to 0.79
# l_hip_pitch: -3.14 to 3.14
# l_knee: -3.14 to 3.14
# l_ankle: -1.40 to 1.40
# r_hip_yaw: -0.79 to 0.79
# r_hip_roll: -0.79 to 0.79
# r_hip_pitch: -3.14 to 3.14
# r_knee: -3.14 to 3.14
# r_ankle: -1.40 to 1.40
# l_shoulder_yaw: -1.40 to 1.40
# l_shoulder_pitch: -3.14 to 1.57
# l_shoulder_roll: -1.40 to 1.40
# l_elbow: -3.00 to 3.00
# r_shoulder_yaw: -1.40 to 1.40
# r_shoulder_pitch: -3.14 to 1.57
# r_shoulder_roll: -1.40 to 1.40
# r_elbow: -3.00 to 3.00
# action_repeat: 1
# action_scale: 0.75
# ang_vel_yaw:
# - -1.0
# - 1.0
# body_height_default: 0.55
# ctrl_dt: 0.02
# delay:
#   hist_len: 10
#   max_delay_step: 10
#   min_delay_step: 0
# episode_length: 1000
# f_dist_range:
# - 0.08
# - 0.4
# history_len: 1
# impl: jax
# lin_vel_x:
# - -1.0
# - 1.0
# lin_vel_y:
# - -1.0
# - 1.0
# nconmax: 65536
# njmax: 60
# noise_config:
#   level: 1.0
#   scales:
#     acc: 0.2
#     faa_pos: 0.03
#     ffe_pos: 0.08
#     gravity: 0.05
#     gyro: 0.2
#     hip_pos: 0.03
#     joint_vel: 1.5
#     kfe_pos: 0.05
#     linvel: 0.1
# obs_hist_len: 40
# obs_size: 67
# push_config:
#   enable: true
#   interval_range:
#   - 5.0
#   - 10.0
#   magnitude_range:
#   - 0.1
#   - 2.0
# reward_config:
#   airtime: 0.45
#   default_p: 0.1
#   feet_f_contact: 5.0
#   max_contact_force: 250.0
#   max_foot_height: 0.1
#   scales:
#     alive: 0.5
#     ang_vel_xy: -0.25
#     contact_force: -0.0
#     dof_pos_limits: -0.25
#     energy: -0.0
#     feet_dist: -0.0
#     feet_height: 2.0
#     feet_slip: -0.75
#     feet_upright: -0.25
#     joint_deviation_hip: -0.25
#     lin_vel_z: -0.15
#     orientation: 1.0
#     pose: -0.5
#     smoothness: -0.0
#     termination: -1.0
#     tracking_ang_vel: 1.5
#     tracking_lin_vel: 2.0
#     undesired_contact: -3.0
# sim_dt: 0.002
# soft_joint_pos_limit_factor: 0.95

# %%
from orbax import checkpoint as ocp
from etils import epath

checkpoint_root = epath.Path(policy_path).expanduser().resolve()

checkpoint_dirs = list(checkpoint_root.glob('*'))
checkpoint_dirs = [ckpt for ckpt in checkpoint_dirs if ckpt.is_dir()]
checkpoint_dirs.sort(key=lambda x: int(x.name))
latest_checkpoint = checkpoint_dirs[-1]
print(f'Loading checkpoint: {latest_checkpoint}')

# Restore
checkpointer = ocp.PyTreeCheckpointer()
loaded_params = checkpointer.restore(latest_checkpoint)

print(loaded_params)

# Fix version mismatch issue from brax
norm_dict = loaded_params[0]
count = norm_dict.get('count', 1)
mean = norm_dict['mean']
std = norm_dict['std']
summed_variance = jax.tree.map(lambda s: jp.square(s) * (count - 1), std)

norm_params = running_statistics.RunningStatisticsState(
    count=count,
    mean=mean,
    summed_variance=summed_variance,
    std=std
)
params = (norm_params, loaded_params[1])
# Out:
# Loading checkpoint: /home/ps/Documents/hector_dev/src/logs/joystick/s1_0906_1_h20/152535040
# [{'count': Array(1.5253504e+08, dtype=float32), 'mean': {'privileged_state': Array([-0.12184128,  0.17708714,  0.0665573 , ...,  0.06729969,
#         0.07292693,  0.07264978], dtype=float32), 'state': Array([-0.12184128,  0.17708714,  0.0665573 , ..., -0.00045657,
#         0.00050652,  0.00102905], dtype=float32)}, 'std': {'privileged_state': Array([1.3725222 , 1.2970293 , 1.349997  , ..., 1.1012919 , 0.09918793,
#        0.0965329 ], dtype=float32), 'state': Array([1.3725222 , 1.2970293 , 1.349997  , ..., 0.54314214, 0.54316914,
#        0.5419703 ], dtype=float32)}, 'summed_variance': {'privileged_state': Array([2.8734813e+08, 2.5660738e+08, 2.7799392e+08, ..., 1.8500117e+08,
#        1.5006772e+06, 1.4214134e+06], dtype=float32), 'state': Array([2.8734813e+08, 2.5660738e+08, 2.7799392e+08, ..., 4.4998352e+07,
#        4.5002828e+07, 4.4804400e+07], dtype=float32)}}, {'params': {'hidden_0': {'bias': Array([-0.18072371, -0.18792717, -0.15775731, ..., -0.21723033,
#        -0.17034422, -0.20234469], dtype=float32), 'kernel': Array([[ 0.11258877, -0.13448438, -0.12958346, ...,  0.16526099,
#         -0.31015328,  0.10183483],
#        [ 0.7702305 ,  0.11766043,  0.39339247, ...,  0.3147882 ,
#         -0.1072739 ,  0.620207  ],
#        [-0.07006446, -0.1406072 ,  0.5625273 , ..., -0.01724254,
#         -0.37424746,  0.32159472],
#        ...,
#        [-0.04192563, -0.01603546,  0.0218811 , ..., -0.01981174,
#         -0.0267483 ,  0.01927065],
#        [ 0.00697833, -0.0549219 ,  0.07483925, ..., -0.05899145,
#         -0.07336649,  0.05380536],
#        [-0.01236426,  0.00926182, -0.03245268, ..., -0.05415519,
#          0.03227434, -0.03130211]], dtype=float32)}, 'hidden_1': {'bias': Array([-3.8406830e-02, -5.6142766e-02, -1.9881507e-02,  3.9260134e-02,
#        -3.9603017e-02, -1.0180593e-01, -7.1331121e-02, -1.1051780e-03,
#         1.47005916e-02, -3.07485964e-02, -1.03092223e-01, -2.26799265e-01,
#         6.90688863e-02,  1.59361083e-02, -2.89861318e-02, -5.65643124e-02,
#        -8.24475214e-02, -1.53926641e-01,  3.55460681e-03,  2.90052742e-02,
#        -1.85471755e-02, -6.36416376e-02,  2.54393239e-02, -5.70490994e-02,
#        -5.33936210e-02,  3.58484909e-02, -1.07642762e-01, -5.11246212e-02,
#        -1.24674156e-01,  5.63918687e-02,  1.27418106e-02,  3.82850394e-02,
#        -1.50300354e-01,  7.16816187e-02,  2.89190542e-02, -4.78407368e-02,
#        -1.46219030e-03,  3.91122662e-02,  8.51434916e-02,  8.14584550e-03],      dtype=float32), 'kernel': Array([[-0.2432406 , -0.03993069, -0.03106551, ..., -0.08150053,
#          0.15742636, -0.02613289],
#        [ 0.11184931, -0.09082407,  0.01187532, ..., -0.0559586 ,
#          0.04342686,  0.0361428 ],
#        [-0.11023326, -0.03971438, -0.00476227, ..., -0.13257635,
#         -0.09401851,  0.19125903],
#        ...,
#        [-0.2114316 ,  0.05391045, -0.02926237, ..., -0.23388806,
#         -0.00288248, -0.06027022],
#        [-0.14075297,  0.01239514,  0.09393618, ..., -0.07752085,
#         -0.04676148, -0.06517586],
#        [-0.00147719,  0.0271346 ,  0.01650802, ..., -0.02285546,
#          0.09846506, -0.04276319]], dtype=float32)}, 'hidden_3': {'bias': Array([-0.03599316], dtype=float32), 'kernel': Array([[ 0.09595362],
#        [ 0.15577237],
#        [-0.16663888],
#        [ 0.01304547],
#        [ 0.16372071],
#        [-0.07259269],
#        [-0.09564929],
#        [ 0.01759517],
#        [-0.09949253],
#        [ 0.03787817],
#        [ 0.03044511],
#        [-0.14290422],
#        [-0.06163028],
#        [ 0.01914391],
#        [ 0.0796361 ],
#        [-0.09177949],
#        [ 0.20675422],
#        [-0.15464653],
#        [-0.12947863],
#        [-0.02790017],
#        [-0.01201066],
#        [ 0.08863473],
#        [-0.11163723],
#        [-0.15542945],
#        [ 0.23647083],
#        [-0.10462167],
#        [-0.04862223],
#        [-0.09300322],
#        [-0.05903894],
#        [ 0.0263425 ],
#        [ 0.10042631],
#        [ 0.001318  ],
#        [ 0.03085043],
#        [ 0.01347722],
#        [-0.09409016],
#        [ 0.20234558],
#        [ 0.02536288],
#        [ 0.03506268],
#        [-0.10324597],
#        [-0.05956896],
#        [-0.07132068],
#        [-0.19068189],
#        [ 0.04007599],
#        [-0.19611667],
#        [-0.01935673],
#        [-0.22706947],
#        [-0.02884173],
#        [-0.08644965],
#        [ 0.04670519],
#        [-0.08168492],
#        [ 0.02673343],
#        [ 0.15042667],
#        [ 0.11101318],
#        [ 0.07998931],
#        [-0.02654702],
#        [ 0.06705528],
#        [ 0.25269213],
#        [-0.16493605],
#        [ 0.0874522 ],
#        [-0.16769178],
#        [-0.22002195],
#        [ 0.02818836],
#        [ 0.0135438 ],
#        [ 0.03373569],
#        [-0.03061062],
#        [ 0.09366176],
#        [ 0.07711035],
#        [ 0.02610665],
#        [ 0.0218404 ],
#        [ 0.04486296],
#        [ 0.05921872],
#        [ 0.08415423],
#        [-0.21016881],
#        [-0.1194747 ],
#        [ 0.04644761],
#        [-0.07702935],
#        [ 0.11934151],
#        [ 0.06658635],
#        [-0.01422248],
#        [ 0.05872017],
#        [ 0.0328881 ],
#        [-0.10073493],
#        [-0.20683864],
#        [-0.13840446],
#        [-0.10168912],
#        [-0.07579935],
#        [-0.03266835],
#        [ 0.04421216],
#        [-0.01999801],
#        [ 0.02813542],
#        [-0.11715857],
#        [-0.11794159],
#        [-0.09029707],
#        [-0.04625523],
#        [ 0.02198179],
#        [-0.02942179],
#        [-0.08394837],
#        [ 0.13936095],
#        [-0.07832673],
#        [ 0.05805646],
#        [-0.15806907],
#        [ 0.11772399],
#        [-0.0583395 ],
#        [ 0.00831774],
#        [-0.10867026],
#        [ 0.25004685],
#        [ 0.02466511],
#        [ 0.05549041],
#        [ 0.16276349],
#        [ 0.04335346],
#        [ 0.00824879],
#        [ 0.1157531 ],
#        [ 0.01404255],
#        [ 0.12938488],
#        [-0.11796878],
#        [ 0.01165652],
#        [ 0.1698081 ],
#        [ 0.00961248],
#        [-0.05963964],
#        [ 0.00648115],
#        [-0.07073236],
#        [-0.09188598],
#        [ 0.0297664 ],
#        [ 0.11554291],
#        [ 0.05814395],
#        [ 0.15184318],
#        [-0.10386072],
#        [-0.18608351],
#        [ 0.23528475],
#        [ 0.04346742],
#        [-0.14614412],
#        [ 0.01035277],
#        [-0.18233566],
#        [-0.06401841],
#        [ 0.01170749],
#        [-0.17913765],
#        [-0.05499046],
#        [ 0.11661011],
#        [-0.02304567],
#        [-0.06426752],
#        [-0.07952271],
#        [ 0.01461386],
#        [ 0.09683336],
#        [-0.12203947],
#        [-0.09182651],
#        [ 0.00295528],
#        [-0.13060752],
#        [ 0.10483563],
#        [ 0.17731036],
#        [ 0.037522  ],
#        [-0.09705947],
#        [-0.11549421],
#        [-0.06703813],
#        [-0.04265232],
#        [ 0.1254646 ],
#        [ 0.07420401],
#        [ 0.11939803],
#        [-0.2098721 ],
#        [ 0.05641325],
#        [-0.09125478],
#        [-0.05685164],
#        [-0.06548717],
#        [ 0.15455091],
#        [ 0.08391166],
#        [-0.09955752],
#        [ 0.1894348 ],
#        [ 0.01587213],
#        [-0.12865064],
#        [-0.09303807],
#        [ 0.03436793],
#        [-0.05879845],
#        [-0.20819059],
#        [-0.2228884 ],
#        [-0.0783629 ],
#        [ 0.03748982],
#        [-0.15162252],
#        [-0.1000061 ],
#        [-0.18223508],
#        [-0.17299242],
#        [-0.09036691],
#        [-0.0955782 ],
#        [-0.11805761],
#        [ 0.39209002],
#        [-0.04489492],
#        [ 0.25981146],
#        [-0.08156385],
#        [ 0.0056496 ],
#        [ 0.0983664 ],
#        [-0.08013661],
#        [-0.18235843],
#        [ 0.20875777],
#        [ 0.01924211],
#        [-0.14172338],
#        [-0.08926049],
#        [ 0.09986055],
#        [-0.16025876],
#        [ 0.08923502],
#        [ 0.01603632],
#        [ 0.03836033],
#        [ 0.04790336],
#        [-0.06113027],
#        [-0.08882362],
#        [-0.09305552],
#        [-0.03267433],
#        [ 0.0475813 ],
#        [ 0.03964639],
#        [ 0.08157644],
#        [-0.03370737],
#        [ 0.1117616 ],
#        [-0.02768433],
#        [-0.0463848 ],
#        [ 0.02196828],
#        [ 0.03963911],
#        [ 0.12464523],
#        [ 0.03929337],
#        [ 0.15417883],
#        [ 0.12768658],
#        [-0.1703806 ],
#        [ 0.03427819],
#        [ 0.17132075],
#        [ 0.06986109],
#        [-0.0981077 ],
#        [ 0.03361678],
#        [-0.13978398],
#        [-0.12142627],
#        [ 0.09240457],
#        [ 0.08326577],
#        [ 0.02593051],
#        [ 0.05273185],
#        [-0.0198589 ],
#        [-0.12792714],
#        [-0.10456204],
#        [-0.07911433],
#        [ 0.12124058],
#        [ 0.03667098],
#        [ 0.01377623],
#        [ 0.00247299],
#        [-0.02452109],
#        [ 0.0266343 ],
#        [ 0.19330588],
#        [-0.02834671],
#        [-0.18432648],
#        [ 0.13418275],
#        [-0.08353933],
#        [-0.04221055],
#        [-0.04384984],
#        [ 0.05146015],
#        [-0.12360669],
#        [ 0.08254252],
#        [ 0.0318119 ],
#        [ 0.06844337],
#        [-0.09148946],
#        [-0.18043268],
#        [-0.15617257],
#        [ 0.0119266 ],
#        [-0.1978791 ]], dtype=float32)}}}]
# /home/ps/Documents/hector_dev/.venv/lib/python3.11/site-packages/orbax/checkpoint/_src/serialization/type_handlers.py:1269: UserWarning: Sharding info not provided when restoring. Populating sharding info from sharding file. Please note restoration time will be slightly increased due to reading from file. Note also that this option is unsafe when restoring on a different topology than the checkpoint was saved with.
#   warnings.warn(

# %%
from brax import base
from brax import envs
from brax import math
from brax.base import Base, Motion, Transform
from brax.base import State as PipelineState
from brax.envs.base import Env, PipelineEnv, State
from brax.io import html, mjcf, model
from brax.mjx.base import State as MjxState
from brax.training.agents.ppo import networks as ppo_networks
from brax.training.agents.ppo import train as ppo
from brax.training.agents.sac import networks as sac_networks
from brax.training.agents.sac import train as sac
from datetime import datetime
import functools

# %%
# Create the inference function with the loaded parameters
network_factory=functools.partial(
  ppo_networks.make_ppo_networks,
  **ppo_params.network_factory,
  # We need to explicitly call the normalization function here since only the brax
  # PPO train.py script creates it if normalize_observations is True.
  preprocess_observations_fn=running_statistics.normalize,
)

ppo_network = network_factory(env.observation_size, env.action_size)
make_inference_fn = ppo_networks.make_inference_fn(ppo_network)
inference_fn = make_inference_fn(params, deterministic=True)

# jit_inference_fn is now ready to be used for rollouts.
jit_inference_fn = jax.jit(inference_fn)
# other jit fcns for rollout, also env for eval
eval_env = registry.load(env_name)
jit_reset = jax.jit(eval_env.reset)
jit_step = jax.jit(eval_env.step)
# Out:
# l_hip_yaw: -0.79 to 0.79
# l_hip_roll: -0.79 to 0.79
# l_hip_pitch: -3.14 to 3.14
# l_knee: -3.14 to 3.14
# l_ankle: -1.40 to 1.40
# r_hip_yaw: -0.79 to 0.79
# r_hip_roll: -0.79 to 0.79
# r_hip_pitch: -3.14 to 3.14
# r_knee: -3.14 to 3.14
# r_ankle: -1.40 to 1.40
# l_shoulder_yaw: -1.40 to 1.40
# l_shoulder_pitch: -3.14 to 1.57
# l_shoulder_roll: -1.40 to 1.40
# l_elbow: -3.00 to 3.00
# r_shoulder_yaw: -1.40 to 1.40
# r_shoulder_pitch: -3.14 to 1.57
# r_shoulder_roll: -1.40 to 1.40
# r_elbow: -3.00 to 3.00

# %%
#Rollout and Render
from mujoco_playground._src.gait import draw_joystick_command
import numpy as np

rng = jax.random.PRNGKey(1)

# Reset action scale to match policy
eval_env._config.action_scale = 0.6 # 0.60 0.75
eval_env._config.obs_hist_len = 20

rollout = []
modify_scene_fns = []

x_vel = 0.5  #@param {type: "number"}
y_vel = 0.0  #@param {type: "number"}
yaw_vel = 0.0  #@param {type: "number"}
body_height = 0.55
body_euler = jp.array([0,0,0])
qarm_left = jp.array([0.0, 0.0, 0.0, 0.0])
qarm_right = jp.array([0.0, 0.0, 0.0, 0.0])
command = jp.array([x_vel, y_vel, yaw_vel])

gait_freq = 1.8 # Hz
phase_dt = 2 * jp.pi * eval_env.dt * gait_freq
phase = jp.array([0, jp.pi])

eval_env._config.push_config.enable=True

for j in range(1):
  print(f"episode {j}")
  state = jit_reset(rng)
  state.info["phase_dt"] = phase_dt
  state.info["phase"] = phase
  for i in range(int(env_cfg.episode_length)):
    act_rng, rng = jax.random.split(rng)
    ctrl, _ = jit_inference_fn(state.obs, act_rng)
    state = jit_step(state, ctrl)
    if state.done:
      break
    state.info["command"] = command
    
    #state.info["command"].at[3].set( 0.5+0.2*jp.sin(phase[0]) )
    
    rollout.append(state)

    xyz = np.array(state.data.xpos[eval_env.mj_model.body("torso").id])
    xyz += np.array([0, 0.0, 0])
    print(xyz)
    x_axis = state.data.xmat[eval_env._torso_body_id, 0]
    yaw = -np.arctan2(x_axis[1], x_axis[0])
    modify_scene_fns.append(
        functools.partial(
            draw_joystick_command,
            cmd=state.info["command"][0:3], # Mask out other command for rendering
            xyz=xyz,
            theta=yaw,
            scl=np.linalg.norm(state.info["command"]),
        )
    )
# Out:
# episode 0
# /home/ps/Documents/hector_dev/.venv/lib/python3.11/site-packages/jax/_src/interpreters/xla.py:132: RuntimeWarning: overflow encountered in cast
#   return np.asarray(x, dtypes.canonicalize_dtype(x.dtype))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 36
#      34 for i in range(int(env_cfg.episode_length)):
#      35   act_rng, rng = jax.random.split(rng)
# ---> 36   ctrl, _ = jit_inference_fn(state.obs, act_rng)
#      37   state = jit_step(state, ctrl)
#      38   if state.done:
#
#     [... skipping hidden 13 frame]
#
# File ~/Documents/hector_dev/.venv/lib/python3.11/site-packages/brax/training/agents/ppo/networks.py:47, in make_inference_fn.<locals>.make_policy.<locals>.policy(observations, key_sample)
#      43 def policy(
#      44     observations: types.Observation, key_sample: PRNGKey
#      45 ) -> Tuple[types.Action, types.Extra]:
#      46   param_subset = (params[0], params[1])  # normalizer and policy params
# ---> 47   logits = policy_network.apply(*param_subset, observations)
#      48   if deterministic:
#      49     return ppo_networks.parametric_action_distribution.mode(logits), {}
#
# File ~/Documents/hector_dev/.venv/lib/python3.11/site-packages/brax/training/networks.py:352, in make_policy_network.<locals>.apply(processor_params, policy_params, obs)
#     350 def apply(processor_params, policy_params, obs):
#     351   if isinstance(obs, Mapping):
# --> 352     obs = preprocess_observations_fn(
#     353         obs[obs_key], normalizer_select(processor_params, obs_key)
#     354     )
#     355   else:
#     356     obs = preprocess_observations_fn(obs, processor_params)
#
# File ~/Documents/hector_dev/.venv/lib/python3.11/site-packages/brax/training/acme/running_statistics.py:217, in normalize(batch, mean_std, max_abs_value)
#     214     data = jnp.clip(data, -max_abs_value, +max_abs_value)
#     215   return data
# --> 217 return jax.tree_util.tree_map(normalize_leaf, batch, mean_std.mean, mean_std.std)
#
#     [... skipping hidden 2 frame]
#
# File ~/Documents/hector_dev/.venv/lib/python3.11/site-packages/brax/training/acme/running_statistics.py:211, in normalize.<locals>.normalize_leaf(data, mean, std)
#     209 if not jnp.issubdtype(data.dtype, jnp.inexact):
#     210   return data
# --> 211 data = (data - mean) / std
#     212 if max_abs_value is not None:
#     213   # TODO(b/124318564): remove pylint directive
#     214   data = jnp.clip(data, -max_abs_value, +max_abs_value)
#
# File ~/Documents/hector_dev/.venv/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:1060, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1059 def op(self, *args):
# -> 1060   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/Documents/hector_dev/.venv/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:579, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     577 args = (other, self) if swap else (self, other)
#     578 if isinstance(other, _accepted_binop_types):
# --> 579   return binary_op(*args)
#     580 # Note: don't use isinstance here, because we don't want to raise for
#     581 # subclasses, e.g. NamedTuple objects that may override operators.
#     582 if type(other) in _rejected_binop_types:
#
# File ~/Documents/hector_dev/.venv/lib/python3.11/site-packages/jax/_src/numpy/ufunc_api.py:180, in ufunc.__call__(self, out, where, *args)
#     178   raise NotImplementedError(f"where argument of {self}")
#     179 call = self.__static_props['call'] or self._call_vectorized
# --> 180 return call(*args)
#
#     [... skipping hidden 13 frame]
#
# File ~/Documents/hector_dev/.venv/lib/python3.11/site-packages/jax/_src/numpy/ufuncs.py:1544, in subtract(x, y)
#    1517 @binary_ufunc(identity=None, at=_subtract_at)
#    1518 def subtract(x: ArrayLike, y: ArrayLike, /) -> Array:
#    1519   """Subtract two arrays element-wise.
#    1520
#    1521   JAX implementation of :obj:`numpy.subtract`. This is a universal function,
#    (...)   1542     Array([-10,  -9,  -8,  -7], dtype=int32)
#    1543   """
# -> 1544   return lax.sub(*promote_args("subtract", x, y))
#
#     [... skipping hidden 9 frame]
#
# File ~/Documents/hector_dev/.venv/lib/python3.11/site-packages/jax/_src/lax/lax.py:132, in _try_broadcast_shapes(name, *shapes)
#     130       result_shape.append(non_1s[0])
#     131     else:
# --> 132       raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#     133                       f'{", ".join(map(str, map(tuple, shapes)))}.')
#     134 return tuple(result_shape)
#
# TypeError: sub got incompatible shapes for broadcasting: (2747,), (1407,).

# %%
# Local ffmpeg
import os
import subprocess

# Add colon separator between paths!
bin_dir = (ROOT_PATH.parent / "visualize" / "ffmpeg" / "ffmpeg-7.0.2-amd64-static")
os.environ["PATH"] = os.pathsep.join([str(bin_dir), os.environ.get("PATH", "")])

print(subprocess.check_output(["ffmpeg", "-version"]).decode())
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
# built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
# libavutil      56. 70.100 / 56. 70.100
# libavcodec     58.134.100 / 58.134.100
# libavformat    58. 76.100 / 58. 76.100
# libavdevice    58. 13.100 / 58. 13.100
# libavfilter     7.110.100 /  7.110.100
# libswscale      5.  9.100 /  5.  9.100
# libswresample   3.  9.100 /  3.  9.100
# libpostproc    55.  9.100 / 55.  9.100

# %%
import mujoco
import mediapy as media

render_every = 1
fps = 1.0 / eval_env.dt / render_every
print(f"fps: {fps}")
traj = rollout[::render_every]
mod_fns = modify_scene_fns[::render_every]

scene_option = mujoco.MjvOption()
scene_option.geomgroup[2] = True
scene_option.geomgroup[3] = False
scene_option.flags[mujoco.mjtVisFlag.mjVIS_CONTACTPOINT] = True
scene_option.flags[mujoco.mjtVisFlag.mjVIS_TRANSPARENT] = False
scene_option.flags[mujoco.mjtVisFlag.mjVIS_PERTFORCE] = False

frames = eval_env.render(
    traj,
    camera="front",
    scene_option=scene_option,
    width=640*2,
    height=480,
    modify_scene_fns=mod_fns,
)
media.show_video(frames, fps=fps, loop=False)
# Out:
# fps: 50.0
# 100%|██████████| 1000/1000 [00:12<00:00, 77.37it/s]
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="1280" height="480" style="object-fit:cover;" autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
# In case save the rollout visualization
render_every = 1
fps = 1.0 / eval_env.dt / render_every

# 4K UHD = 3840×2160
#frames = eval_env.render(
#    rollout[::render_every],
#    camera="front",
#    scene_option=scene_option,
#    width=1920,
#    height=1080,
#    modify_scene_fns=modify_scene_fns[::render_every],
#)

#import mediapy as media
#from datetime import datetime
#fname = f"video/hector/rollout_{datetime.now():%Y%m%d-%H%M%S}_4k.mp4"

#media.write_video(fname, frames, fps=fps)

# %%
import matplotlib.pyplot as plt
import numpy as np

# This cell assumes 'rollout' and 'eval_env' are available from the previous cell.

# Extract the actual Z-height and commanded Z-height from the rollout data
actual_z_heights = [state.data.qpos[2] for state in rollout]
commanded_z_heights = [state.info['command'][3] for state in rollout]
time_steps = [i * eval_env.dt for i in range(len(rollout))]

# Create the plot
plt.figure(figsize=(15, 7))

# Plot actual and commanded height
plt.plot(time_steps, actual_z_heights, label='Actual Z-Height', color='dodgerblue', linewidth=2)
plt.plot(time_steps, commanded_z_heights, label='Commanded Z-Height', color='red', linestyle='--', linewidth=2)

# Add plot details
plt.title('Robot Torso Z-Height Tracking', fontsize=16)
plt.xlabel('Time (s)', fontsize=12)
plt.ylabel('Height (m)', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True, linestyle=':')
plt.show()
